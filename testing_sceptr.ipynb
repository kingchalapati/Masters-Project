# %%
pip install sceptr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 14.4 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 26.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [sceptr]2m1/4 [torch]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sceptr

# %%
tcrs = pd.DataFrame(
    data = {
            "TRAV": ["TRAV38-1*01", "TRAV3*01", "TRAV13-2*01", "TRAV38-2/DV8*01"],
            "CDR3A": ["CAHRSAGGGTSYGKLTF", "CAVDNARLMF", "CAERIRKGQVLTGGGNKLTF", "CAYRSAGGGTSYGKLTF"],
            "TRBV": ["TRBV2*01", "TRBV25-1*01", "TRBV9*01", "TRBV2*01"],
            "CDR3B": ["CASSEFQGDNEQFF", "CASSDGSFNEQFF", "CASSVGDLLTGELFF", "CASSPGTGGNEQYF"],
    },
    index = [0,1,2,3]
)

# %%
print(tcrs)
# Out:
#               TRAV                 CDR3A         TRBV            CDR3B
# 0      TRAV38-1*01     CAHRSAGGGTSYGKLTF     TRBV2*01   CASSEFQGDNEQFF
# 1         TRAV3*01            CAVDNARLMF  TRBV25-1*01    CASSDGSFNEQFF
# 2      TRAV13-2*01  CAERIRKGQVLTGGGNKLTF     TRBV9*01  CASSVGDLLTGELFF
# 3  TRAV38-2/DV8*01     CAYRSAGGGTSYGKLTF     TRBV2*01   CASSPGTGGNEQYF

# %%
topleft = sceptr.calc_cdist_matrix(tcrs.iloc[:2], tcrs.iloc[:2])
topright = sceptr.calc_cdist_matrix(tcrs.iloc[2:], tcrs.iloc[:2])
bottomleft = sceptr.calc_cdist_matrix(tcrs.iloc[:2], tcrs.iloc[2:])
bottomright = sceptr.calc_cdist_matrix(tcrs.iloc[2:], tcrs.iloc[2:])

# %%
import numpy as np

full = np.block([
    [topleft, topright],
    [bottomleft, bottomright]
])

# %%
print(full)
# Out:
# [[0.         1.413599   1.2849894  1.4653425 ]
#  [1.413599   0.         0.75219345 1.4646543 ]
#  [1.2849894  0.75219345 0.         1.287208  ]
#  [1.4653425  1.4646543  1.287208   0.        ]]

# %%
file1 = pd.read_csv("../Data/20260116 Comparison 3/20251223 BL6-B10BR HTx HIL Clonotypes with ADT Counts.csv")
