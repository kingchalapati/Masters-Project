# %% [markdown]
# ### Building the per cell plot csvs for mou

# %%
import polars as pl
from pathlib import Path

# %%
b10br_hil_df_zerodex = pl.read_csv(
    'Comparison3_Samplewise_Outputs/B10BR_HIL/per_cell_proportions_ranked_zerodex.csv'
    ).filter(pl.col('clonotype').is_in([
        'AV16N-CAMREANTGYQNFYF-AJ49_BV13-2-CASGDGAQNTLYF-BJ2-4',
        'AV13-2-CAPNNNAGAKLTF-AJ39_BV14-CASSDRYEQYF-BJ2-7',
        'AV14-2-CAASASSGSWQLIF-AJ22_BV31-CAWSLAGSGNTLYF-BJ1-3'
    ]))

d7abc_ll_df_zerodex = pl.read_csv(
    'Comparison3_Samplewise_Outputs/D7ABC_LL/per_cell_proportions_ranked_zerodex.csv'
    ).filter(pl.col('clonotype').is_in([
        'AV16-CAMREANTGYQNFYF-AJ49_BV13-2-CASGDGAQNTLYF-BJ2-4',
        'AV13-2-CAPNNNAGAKLTF-AJ39_BV14-CASSDRYEQYF-BJ2-7',
        'AV14-2-CAASASSGSWQLIF-AJ22_BV31-CAWSLAGSGNTLYF-BJ1-3'
    ]))

# %%
b10br_hil_df_zerodex.write_csv('Comparison3_Samplewise_Outputs/B10BR_HIL/selected_clonotypes_b10br_zerodex.csv')
d7abc_ll_df_zerodex.write_csv('Comparison3_Samplewise_Outputs/D7ABC_LL/selected_clonotypes_d7abc_zerodex.csv')
