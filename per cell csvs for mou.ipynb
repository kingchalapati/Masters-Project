# %% [markdown]
# ### Building the per cell plot csvs for mou

# %%
import polars as pl
from pathlib import Path

# %%
b10br_hil_df = pl.read_csv('Comparison3_Samplewise_Outputs/B10BR_HIL/per_cell_proportions_ranked.csv').filter(pl.col('clonotype_rank').is_in([254, 269, 370]))

d7abc_ll_df = pl.read_csv('Comparison3_Samplewise_Outputs/D7ABC_LL/per_cell_proportions_ranked.csv').filter(pl.col('clonotype_rank').is_in([7, 169, 97]))

# %%
b10br_hil_df.write_csv('Comparison3_Samplewise_Outputs/B10BR_HIL/selected_clonotypes_b10br.csv')
d7abc_ll_df.write_csv('Comparison3_Samplewise_Outputs/D7ABC_LL/selected_clonotypes_d7abc.csv')
